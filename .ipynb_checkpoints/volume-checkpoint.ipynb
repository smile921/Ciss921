# %% [markdown]
# # 找出今天成交量是昨天的几倍的股票
#
# - 剔除停牌的
# - 剔除一字板的
# - 剔除新股
# - 剔除st股
# - TODO

# %%
import tushare as ts
dfsh = ts.get_hist_data('sh',start='2016-01-05')
date = list(dfsh.index)
[today,last] = date[0:2]
df = ts.get_today_all() 
lastData = df.loc[:,['code','name','volume']]
lastData.to_json(today+'-unicode.json',orient='records')
lastData.to_json(today+'-gbk.json',orient='records',force_ascii=False) 
df.to_json(today+'-gbk-all.json',orient='records',force_ascii=False)
# Out:
# [Getting data:]#####################################

# %%
import tushare as ts
import pandas as pd
import numpy as np
dfsh = ts.get_hist_data('sh',start='2016-01-05')
date = list(dfsh.index)
[today,last] = date[0:2]
dft = pd.read_json(today+'-gbk-all.json',orient='records', typ='frame',numpy=False) 
dfy = pd.read_json(last+'-gbk-all.json',orient='records', typ='frame',numpy=False) 
# print dft.head()
# print dft.ix[2268]
# print '-------------------------'
# print dfy.ix[2268]
# print '-------------------------'
# print dft.index
# print dft.columns
# print dft.shape
# pandas.read_json(path_or_buf=None, orient=None, typ='frame', dtype=True, convert_axes=True, 
# convert_dates=True, keep_default_dates=True, numpy=False, precise_float=False, date_unit=None)¶
# Convert a JSON string to pandas object
tdata = dft.loc[:,['code','name','volume']]
ydata = dfy.loc[:,['code','name','volume']]

tdata =  tdata.set_index(['code'])
ydata =  ydata.set_index(['code'])

# tdata.set_index(['code'])
# print tdata.set_index(['code'])['300146',:]
# print tdata.set_index(['code'])
# print tdata.set_index('code',inplace=True).index
# print tdata.set_index(['code']).index|
# print tdata.shape
# print ydata.shape
# print '-------------------------'
# print tdata.ix[2268]
# print '-------------------------' 
# print ydata.ix[2268]
# print '-------------------------'

tdata['volumeLast']=ydata['volume']
tdata['rate']= tdata['volume']/tdata['volumeLast']
tdata.columns

# print '-------------------------'
# print tdata.ix[2268]
# print '-------------------------'
alpha =1000
data = tdata[(tdata.volume>alpha) & (tdata.volumeLast>alpha) & (tdata.rate<20)].sort_values(by='rate')
data.sort_values(by='rate').to_excel('a.xls');
date  = [today,last]
print date 
print '------------------------------------------------------'
print data.head(10)
print  '\t\t\n'
print data.tail(10)
print '------------------------------------------------------'
print data[(data.rate>2) & (data.rate <5) ].head(20)
print  '\t\t\n'
print data[(data.rate>2) & (data.rate <5) ].tail(20)
print  '\t\t\n'
# data =   pd.concat({'code':tdata.loc[:,['code']], 'name':tdata.loc[:,['name']], 'AA':tdata.loc[:,['volume']],'BB':ydata.loc[:,['volume']] }, axis=1)
# data.head()
# data['rate']= data['AA']/data['BB']
# # data.reset_index(level=['code','name','AA','BB','rate'])
# data.reindex(level=['code','name','AA','BB','rate'] )
# data.sort_values(by='rate').to_excel('a.xls');
# data.columns
# data[data.AA>0]
# data[(data['volume'] > 10)]
# datasorted = data[(data.volume > 10) & (data.volume-lastday>10)].sort_values(by='rate')
# datasorted.dropna(how='any').head()
 
# datasorted.dropna(how='any').tail()
# datasorted.tail()

# def f(x):
#     return 99;
# data['rate'] = data.applymap(f).all(axis=1).astype(float)
# data.as_matrix()
# tt = np.array(data)
# data.head()
# tt
# Out:
# amount             183458250
# changepercent          2.668
# code                  300146
# high                   32.43
# low                     31.6
# mktcap           2.35293e+06
# name                    汤臣倍健
# nmc              1.16375e+06
# open                    31.6
# pb                     5.209
# per                   41.974
# settlement             31.48
# trade                  32.32
# turnoverratio        1.58276
# volume               5699058
# Name: 2268, dtype: object
# -------------------------
# amount              44075448
# changepercent         -1.892
# code                  600809
# high                   15.65
# low                     15.2
# mktcap           1.34726e+06
# name                    山西汾酒
# nmc              1.34726e+06
# open                    15.2
# pb                     3.157
# per                   37.868
# settlement             15.86
# trade                  15.56
# turnoverratio        0.32882
# volume               2847052
# Name: 2268, dtype: object
# -------------------------
# (2784, 2)
# (2784, 2)
# -------------------------
# name         卫 士 通
# volume    10677203
# Name: 2268, dtype: object
# -------------------------
# name        卫 士 通
# volume    4992391
# Name: 2268, dtype: object
# -------------------------
# -------------------------
# name             卫 士 通
# volume        10677203
# volumeLast     4992391
# rate            2.1387
# Name: 2268, dtype: object
# -------------------------
# [u'2016-02-16', u'2016-02-15']
# ------------------------------------------------------
#         name    volume  volumeLast      rate
# code
# 300130   新国都   1424956     6163539  0.231191
# 520     长航凤凰  17524888    73054499  0.239888
# 2423    中原特钢   6382779    22070729  0.289197
# 603377  东方时尚     28317       84637  0.334570
# 601900  南方传媒     46965      135712  0.346064
# 600789  鲁抗医药  12527512    31861032  0.393192
# 600318  巢东股份    778715     1928274  0.403840
# 600234  山水文化   9286175    18787698  0.494269
# 603869  北部湾旅   7478630    13612609  0.549390
# 300500  苏州设计      7034       12760  0.551254
#
#
#         name    volume  volumeLast       rate
# code
# 928     中钢国际  23248907     5772228   4.027718
# 42      中洲控股   7172306     1697137   4.226121
# 600988  赤峰黄金  47972092    11339017   4.230710
# 2208    合肥城建   6331412     1407750   4.497540
# 300420  五洋科技   2545379      470638   5.408358
# 600377  宁沪高速  14749111     2345340   6.288688
# 18      神州长城  18496410     2621184   7.056510
# 2237    恒邦股份  85248830    11306368   7.539895
# 2174    游族网络  13264319     1018100  13.028503
# 2373    千方科技   9698360      628700  15.426054
# ------------------------------------------------------
#         name    volume  volumeLast      rate
